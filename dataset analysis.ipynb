# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
# Importing data
PATH = r"D:\Projects\moveilens"
df_tag = pd.DataFrame(pd.read_csv(fr"{PATH}\tag.csv"))
df_movie = pd.DataFrame(pd.read_csv(fr"{PATH}\movie.csv"))
df_rating = pd.DataFrame(pd.read_csv(fr"{PATH}\rating.csv"))
df_link = pd.DataFrame(pd.read_csv(fr"{PATH}\link.csv"))
df_genome_tags = pd.DataFrame(pd.read_csv(fr"{PATH}\genome_tags.csv"))
df_genome_scores = pd.DataFrame(pd.read_csv(fr"{PATH}\genome_scores.csv"))

# %%
df_tag.head()
# Out:
#    userId  movieId            tag            timestamp
# 0      18     4141    Mark Waters  2009-04-24 18:19:40
# 1      65      208      dark hero  2013-05-10 01:41:18
# 2      65      353      dark hero  2013-05-10 01:41:19
# 3      65      521  noir thriller  2013-05-10 01:39:43
# 4      65      592      dark hero  2013-05-10 01:41:18

# %%
df_movie.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
df_rating.head()
# Out:
#    userId  movieId  rating            timestamp
# 0       1        2     3.5  2005-04-02 23:53:47
# 1       1       29     3.5  2005-04-02 23:31:16
# 2       1       32     3.5  2005-04-02 23:33:39
# 3       1       47     3.5  2005-04-02 23:32:07
# 4       1       50     3.5  2005-04-02 23:29:40

# %%
df_link.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
df_genome_tags.head()
# Out:
#    tagId           tag
# 0      1           007
# 1      2  007 (series)
# 2      3  18th century
# 3      4         1920s
# 4      5         1930s

# %%
df_genome_scores.head()
# Out:
#    movieId  tagId  relevance
# 0        1      1    0.02500
# 1        1      2    0.02500
# 2        1      3    0.05775
# 3        1      4    0.09675
# 4        1      5    0.14675

# %%
# Demonstrating sparsity of the data
pivoted_df = df_rating.iloc[:100000].pivot(index='userId', columns='movieId', values='rating')
pivoted_df.head(10)
# Out:
# movieId  1       2       3       4       5       6       7       8       \
# userId
# 1           NaN     3.5     NaN     NaN     NaN     NaN     NaN     NaN
# 2           NaN     NaN     4.0     NaN     NaN     NaN     NaN     NaN
# 3           4.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4           NaN     NaN     NaN     NaN     NaN     3.0     NaN     NaN
# 5           NaN     3.0     NaN     NaN     NaN     NaN     NaN     NaN
# 6           5.0     NaN     3.0     NaN     NaN     NaN     5.0     NaN
# 7           NaN     NaN     3.0     NaN     NaN     NaN     3.0     NaN
# 8           4.0     NaN     5.0     NaN     NaN     3.0     NaN     NaN
# 9           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 10          4.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# movieId  9       10      ...  117511  117590  118354  118696  118900  118997  \
# userId                   ...
# ...

# %%
# Sparsity plot
plt.spy(pivoted_df.values, aspect='auto')

# %%
# Some numbers
num_users = len(df_rating['userId'].value_counts().index)
num_films = len(df_rating['movieId'].value_counts().index)
print(f"Number of users: {num_users}; Number of films: {num_films}")
# Out:
# Number of users: 138493; Number of films: 26744
